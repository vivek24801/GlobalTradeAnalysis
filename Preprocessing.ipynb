# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
exchange_df = pd.read_excel('/Users/vivek/Desktop/GlobalTradeAnalysis/Datasets/Exchange rate, new LCU per USD extended backward, period average.xlsx')
exchange_df.head()
# Out:
#    Unnamed: 0  Afghanistan    Angola   Albania  Advanced Economies  \
# 0         NaN          NaN       NaN       NaN                 NaN
# 1      1996.0     47.50000  110941.4  101.8028            36.86064
# 2      1997.0     47.50000  228814.8  148.6727            42.71796
# 3      1998.0     47.50000  273251.9  152.4996            57.50503
# 4      1999.0     46.62167  168333.9  137.4677            49.36311
#
#    United Arab Emirates  Argentina   Armenia  Antigua and Barbuda  Australia  \
# 0                   NaN        NaN       NaN                  NaN        NaN
# 1              3.672184   1.000144  414.0408             2.699928   1.277522
# 2              3.672193   0.999992  490.8467             2.696925   1.347961
# 3              3.673000   1.000000  504.9150             2.697102   1.591508
# 4              3.672881   0.999656  535.0617             2.697299   1.549667
#
#    ...  Venezuela, RB  Viet Nam   Vanuatu  World (WBG members)     Samoa  \
# ...

# %%
exchange_df.rename(columns={'Unnamed: 0':'Year'},inplace=True)

# %%
exchange_df.drop(index=0,inplace=True)

# %%
exchange_df.isnull().sum().sort_values(ascending=False)
# Out:
# Emerging Market and Developing Economies (EMDEs)    30
# Middle-Income Countries (MIC)                       30
# World (WBG members)                                 30
# EMDE Middle East & N. Africa                        30
# Turkmenistan                                        24
#                                                     ..
# Chile                                                0
# EMDE Latin America & Caribbean                       0
# Lebanon                                              0
# Switzerland                                          0
# Year                                                 0
# Length: 200, dtype: int64

# %%
missing_values = exchange_df.isnull().sum()

# %%
exports_df = pd.read_excel('/Users/vivek/Desktop/GlobalTradeAnalysis/Datasets/Exports Merchandise, Customs, current US$, millions, seas. adj..xlsx')

# %%
exports_df.head()##
# Out:
#    Unnamed: 0    Angola   Albania  Advanced Economies  Argentina   Armenia  \
# 0         NaN       NaN       NaN                 NaN        NaN       NaN
# 1      1996.0  4786.248  243.3936           4177347.0    23809.0  280.8546
# 2      1997.0  5557.728  138.5836           4225058.0    26431.0  232.9667
# 3      1998.0  6334.723  225.4329           4208282.0    26432.0  226.2707
# 4      1999.0  7117.929  262.5939           4293584.0    23310.0  232.0850
#
#    Australia   Austria  Azerbaijan   Burundi  ...    Uganda   Ukraine  \
# 0        NaN       NaN         NaN       NaN  ...       NaN       NaN
# 1   60233.37  57831.90         NaN  34.70724  ...  641.2139  14407.15
# 2   62835.03  58533.66         NaN  89.50987  ...  585.7458  14272.31
# 3   55899.17  62637.14    674.9803  64.64187  ...  513.7654  12672.46
# 4   55976.20  64162.50   1012.4520  52.75181  ...  479.4672  11560.96
#
#     Uruguay  United States  Venezuela, RB  Viet Nam  World (WBG members)  \
# ...

# %%
exports_df.rename(columns={'Unnamed: 0':'Year'},inplace=True)
exports_df.drop(index=0,inplace=True)

# %%
exports_df.head()
# Out:
#      Year    Angola   Albania  Advanced Economies  Argentina   Armenia  \
# 1  1996.0  4786.248  243.3936           4177347.0    23809.0  280.8546
# 2  1997.0  5557.728  138.5836           4225058.0    26431.0  232.9667
# 3  1998.0  6334.723  225.4329           4208282.0    26432.0  226.2707
# 4  1999.0  7117.929  262.5939           4293584.0    23310.0  232.0850
# 5  2000.0  7678.276  258.9664           4648732.0    26340.0  292.9429
#
#    Australia   Austria  Azerbaijan   Burundi  ...    Uganda   Ukraine  \
# 1   60233.37  57831.90         NaN  34.70724  ...  641.2139  14407.15
# 2   62835.03  58533.66         NaN  89.50987  ...  585.7458  14272.31
# 3   55899.17  62637.14    674.9803  64.64187  ...  513.7654  12672.46
# 4   55976.20  64162.50   1012.4520  52.75181  ...  479.4672  11560.96
# 5   63747.35  64227.07   1857.3480  48.60067  ...  439.9637  14551.35
#
#     Uruguay  United States  Venezuela, RB   Viet Nam  World (WBG members)  \
# ...

# %%
exports_df.isnull().sum().sort_values(ascending=False)
# Out:
# Tanzania, United Rep.    26
# Rwanda                   23
# Myanmar                  22
# Seychelles               22
# Maldives                 22
#                          ..
# Hong Kong SAR, China      2
# High Income Countries     2
# United Kingdom            2
# France                    2
# Year                      0
# Length: 140, dtype: int64

# %%
imports_df = pd.read_excel('/Users/vivek/Desktop/GlobalTradeAnalysis/Datasets/Imports Merchandise, Customs, current US$, millions, seas. adj..xlsx')

# %%
imports_df.head()
# Out:
#    Unnamed: 0    Albania  Advanced Economies  Argentina   Armenia  Australia  \
# 0         NaN        NaN                 NaN        NaN       NaN        NaN
# 1      1996.0   947.5612           4035001.0    23762.0  847.9732   61454.51
# 2      1997.0   497.6711           4116827.0    30452.0  900.3036   61853.03
# 3      1998.0   816.5439           4116672.0    31377.0  904.1901   60738.51
# 4      1999.0  1131.2480           4342590.0    25506.0  801.1627   65324.59
#
#     Austria   Burundi   Belgium  Bangladesh  ...     Uganda  Ukraine  \
# 0       NaN       NaN       NaN         NaN  ...        NaN      NaN
# 1  66950.13  123.2563  162122.2         NaN  ...  1181.4950  17670.4
# 2  64974.49  123.4582  157565.4         NaN  ...  1297.2930  17118.2
# 3  68196.70  155.9690  164829.7         NaN  ...   987.9321  14693.1
# 4  69605.99  118.9108  164608.1         NaN  ...  1347.7080  11781.1
#
#     Uruguay  United States  Venezuela, RB  Viet Nam  World (WBG members)  \
# ...

# %%
imports_df.rename(columns={'Unnamed: 0':'Year'},inplace=True)
imports_df.drop(index=0,inplace=True)

# %%
imports_df.isnull().sum().sort_values(ascending=False)
# Out:
# Cyprus                     20
# Qatar                      19
# EMDE Sub-Saharan Africa    17
# Dominican Republic         16
# South Africa               16
#                            ..
# Guatemala                   2
# World (WBG members)         2
# Korea, Rep.                 1
# Turkey                      1
# Year                        0
# Length: 122, dtype: int64

# %%
gdp_df = pd.read_excel('/Users/vivek/Desktop/GlobalTradeAnalysis/Datasets/GDP at market prices, current US$, millions, seas. adj..xlsx')

# %%
gdp_df.rename(columns={'Unnamed: 0':'Year'},inplace=True)
gdp_df.drop(index=0,inplace=True)

# %%
gdp_df.head()
# Out:
#      Year  Albania  Advanced Economies  Argentina   Armenia  Australia  \
# 1  1996.0      NaN          25537709.0   304162.6       NaN   424835.8
# 2  1997.0      NaN          25025058.0   327324.5       NaN   425689.5
# 3  1998.0      NaN          25127560.0   334208.9       NaN   381265.2
# 4  1999.0      NaN          26454858.0   317253.9       NaN   412018.7
# 5  2000.0      NaN          26899647.0   318021.7  2105.325   399609.9
#
#     Austria   Belgium  Bulgaria  Bahrain  ...  Thailand   Tunisia    Turkey  \
# 1  234250.3  276714.3  13731.15      NaN  ...  182968.0       NaN  249310.7
# 2  212462.8  253536.6  11333.61      NaN  ...  156986.3       NaN  265984.3
# 3  217461.3  259194.1  15015.97      NaN  ...  114644.2       NaN  272675.6
# 4  216256.3  258289.0  13587.52      NaN  ...  126556.0       NaN  252530.4
# 5  196276.2  236655.2  13258.57      NaN  ...  126396.2  22582.48  272995.0
#
#    Taiwan, China  Ukraine   Uruguay  United States  Uzbekistan  \
# ...

# %%
gdp_df.isnull().sum().sort_values(ascending=False)
# Out:
# Low-Income Countries (LIC)    30
# Sri Lanka                     15
# Nigeria                       15
# EMDE Sub-Saharan Africa       15
# Kuwait                        15
#                               ..
# United Kingdom                 1
# France                         1
# Finland                        1
# Estonia                        1
# Year                           0
# Length: 105, dtype: int64
